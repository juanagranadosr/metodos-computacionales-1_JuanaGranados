# %%
import urllib.request

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import pandas as pd
import sympy as sym
import os.path as path
import os
from sympy import lambdify

#import wget

# %%
if not path.exists('Data'):
    os.mkdir('Data')

# %%
X = np.array([1,2,3,4,5])
Y = np.array([1,2,3,4,5])

# %%
def Lagrange(x, xi, i):
    """ x es el punto que se quiere aproximar
        xi son todos los puntos de la función original
        i es la iteración de los puntos de la función original
        """
    prod = 1.
    n = len(xi)
    
    for j in range(n):
        if i!=j:
            prod *= (x - xi[j])/(xi[i]-xi[j])
    return prod

# %%
def Interpolate(x, xi, yi):
    """ x es el punto que se quiere aproximar
        xi son todos los puntos del eje x de la función original
        yi son los puntos del eje Y de la función original
        """
    Sum = 0
    n = len(xi)
    
    for j in range(n):
        Sum += yi[j]*Lagrange(x, xi, j)
        
    return Sum

# %%
x = np.linspace(X[0],X[-1],100)
y = Interpolate(x,X,Y)

plt.scatter(X,Y,marker='o', color='b')
plt.plot(x,y,color='k')

# %%
x = sym.Symbol('x', real=True)

f = Interpolate(x, X, Y)
f1 = sym.simplify(f)

# %%
func = lambdify([x], f1, modules='numpy')

# %%
def der_func(x,h):
    return (func(x+h)-func(x-h))/(2*h)

def der2_func(x,h):
    return (func(x+h)-2*func(x)+func(x-h))/(h**2)

def newtrap (x):
    return x-(der_func(x,0.0001)/der2_func(x,0.0001))


x1=1
for i in range(100):
    X1 = x1
    x1 = newtrap(x1)
    if np.abs(X1-x1)<=(10**(-6)):
        sol = x1

func(sol)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /var/folders/qn/vxgw72n52zv0lbnxjfvcc8zr0000gn/T/ipykernel_25606/2500281971.py in <module>
#      12 for i in range(100):
#      13     X1 = x1
# ---> 14     x1 = newtrap(x1)
#      15     if np.abs(X1-x1)<=(10**(-6)):
#      16         sol = x1
#
# /var/folders/qn/vxgw72n52zv0lbnxjfvcc8zr0000gn/T/ipykernel_25606/2500281971.py in newtrap(x)
#       6
#       7 def newtrap (x):
# ----> 8     return x-(der_func(x,0.0001)/der2_func(x,0.0001))
#       9
#      10
#
# ZeroDivisionError: float division by zero

# %%
x = np.linspace(X[0],X[-1],100)
y = Interpolate(x,X,Y)

plt.scatter(X,Y,marker='o', color='b')
plt.plot(x,y,color='k')

plt.plot([X[0],X[-1]],[func(sol),func(sol)],"r")
plt.plot([sol,sol],[-7,Y[-1]],"r")

#plt.scatter(sol, func(sol),color= 'r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/qn/vxgw72n52zv0lbnxjfvcc8zr0000gn/T/ipykernel_25606/3279285057.py in <module>
#       5 plt.plot(x,y,color='k')
#       6
# ----> 7 plt.plot([X[0],X[-1]],[func(sol),func(sol)],"r")
#       8 plt.plot([sol,sol],[-7,Y[-1]],"r")
#       9
#
# NameError: name 'sol' is not defined
